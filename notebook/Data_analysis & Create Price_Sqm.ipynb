# %% [markdown]
# # Import libraries and load dataset

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)

# %matplotlib inline

# %%
url = "https://raw.githubusercontent.com/kaiyungtan/challenge-data-analysis/master/data/clean/belgium_real_estate.csv"

df = pd.read_csv(url,index_col=0)
 
df.head()
# Out:
#    postal_code city_name  type_of_property   price  number_of_rooms  \
# 0         1050   Ixelles                 0  340000                6
# 1         1050   Ixelles                 0  520000                4
# 2         1050   Ixelles                 0  599000                4
# 3         1050   Ixelles                 0  599000                3
# 4         1050   Ixelles                 0  575000                3
#
#    house_area  fully_equipped_kitchen  open_fire  terrace  garden  \
# 0         203                       1          0        1       0
# 1         200                       0          0        0       0
# 2         160                       1          0        1       1
# 3         160                       1          0        1       1
# 4         171                       0          0        0       0
#
#    surface_of_the_land  number_of_facades  swimming_pool  \
# 0                   95                  2              0
# 1                   69                  2              0
# 2                  100                  2              0
# 3                  130                  2              0
# 4                   46                  2              0
#
#   state_of_the_building  lattitude  longitude            province     region
# 0         to be done up   4.381571  50.822285  Bruxelles-Capitale  Bruxelles
# 1           to renovate   4.381571  50.822285  Bruxelles-Capitale  Bruxelles
# 2         to be done up   4.381571  50.822285  Bruxelles-Capitale  Bruxelles
# 3                  good   4.381571  50.822285  Bruxelles-Capitale  Bruxelles
# 4        just renovated   4.381571  50.822285  Bruxelles-Capitale  Bruxelles

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40395 entries, 0 to 40394
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   postal_code             40395 non-null  int64
#  1   city_name               40395 non-null  object
#  2   type_of_property        40395 non-null  int64
#  3   price                   40395 non-null  int64
#  4   number_of_rooms         40395 non-null  int64
#  5   house_area              40395 non-null  int64
#  6   fully_equipped_kitchen  40395 non-null  int64
#  7   open_fire               40395 non-null  int64
#  8   terrace                 40395 non-null  int64
#  9   garden                  40395 non-null  int64
#  10  surface_of_the_land     40395 non-null  int64
#  11  number_of_facades       40395 non-null  int64
#  12  swimming_pool           40395 non-null  int64
#  13  state_of_the_building   40395 non-null  object
#  14  lattitude               40395 non-null  float64
#  15  longitude               40395 non-null  float64
#  16  province                40395 non-null  object
#  17  region                  40395 non-null  object
# dtypes: float64(2), int64(12), object(4)
# memory usage: 5.9+ MB

# %%
df.isna().sum()
# Out:
# postal_code               0
# city_name                 0
# type_of_property          0
# price                     0
# number_of_rooms           0
# house_area                0
# fully_equipped_kitchen    0
# open_fire                 0
# terrace                   0
# garden                    0
# surface_of_the_land       0
# number_of_facades         0
# swimming_pool             0
# state_of_the_building     0
# lattitude                 0
# longitude                 0
# province                  0
# region                    0
# dtype: int64

# %%
df.shape
# Out:
# (40395, 18)

# %%
df.describe()
# Out:
#         postal_code  type_of_property          price  number_of_rooms  \
# count  40395.000000      40395.000000   40395.000000     40395.000000
# mean    5195.044139          0.469241  314114.661617         2.813838
# std     2979.185308          0.499059  168151.672366         1.260968
# min     1000.000000          0.000000    2500.000000         1.000000
# 25%     2360.000000          0.000000  199000.000000         2.000000
# 50%     4630.000000          0.000000  275000.000000         3.000000
# 75%     8400.000000          1.000000  379000.000000         3.000000
# max     9992.000000          1.000000  950000.000000        18.000000
#
#          house_area  fully_equipped_kitchen     open_fire       terrace  \
# count  40395.000000            40395.000000  40395.000000  40395.000000
# mean     152.466320                0.697512      0.053596      0.620176
# std       95.649206                0.459341      0.225221      0.485349
# min        5.000000                0.000000      0.000000      0.000000
# 25%       92.000000                0.000000      0.000000      0.000000
# 50%      130.000000                1.000000      0.000000      1.000000
# 75%      184.000000                1.000000      0.000000      1.000000
# max     3560.000000                1.000000      1.000000      1.000000
#
#              garden  surface_of_the_land  number_of_facades  swimming_pool  \
# count  40395.000000         40395.000000       40395.000000   40395.000000
# mean       0.321228           545.840079           2.071494       0.017230
# std        0.466954          3609.242736           1.416501       0.130128
# min        0.000000             0.000000           0.000000       0.000000
# 25%        0.000000             0.000000           0.000000       0.000000
# 50%        0.000000             0.000000           2.000000       0.000000
# 75%        1.000000           416.000000           3.000000       0.000000
# max        1.000000        400000.000000           4.000000       1.000000
#
#           lattitude     longitude
# count  40395.000000  40395.000000
# mean       4.313450     50.853864
# std        0.811989      0.325111
# min        2.580670     49.508502
# 25%        3.714155     50.670189
# 50%        4.361195     50.870452
# 75%        4.849315     51.104485
# max        6.300938     51.474352

# %%
df.describe(include='object')
# Out:
#         city_name state_of_the_building             province   region
# count       40395                 40395                40395    40395
# unique       1046                     7                   11        3
# top     Antwerpen                as new  Flandre-Occidentale  Flandre
# freq          886                 12096                 7235    24038

# %%
# rename columns lattitude --> longitude & longitude --> lattitude

df.rename(columns={'lattitude': 'longitude', 'longitude': 'lattitude'}, inplace=True)

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ## Price

# %%
# check the distribution of the price

plt.hist(df['price'], bins=50);

# %%
sns.distplot(df['price'], hist=False)

# %%
# closer look at the distribution by plotting a simple histogram with 10 bins.

plt.figure(figsize=(20,10));  # makes the plot wider
plt.hist(df['price'], color='r');  # plots a simple histogram
plt.axvline(df['price'].mean(), color='m', linewidth=3,label='Mean')  # draw a line for mean
plt.axvline(df['price'].median(), color='b', linestyle='dashed', linewidth=3,label='Medium') # draw a line for median
plt.axvline(df['price'].mode()[0], color='g', linestyle='dashed', linewidth=3,label='Mode') # draw a line for mode

plt.title('Price for houses & apartment in Belgium')
plt.xlabel('Price')    # label the x-axis
plt.ylabel('Numbers of house or apartment')    # label the y-axis
plt.legend()      # Plot the legend

mean=round(df['price'].mean())
median=round(df['price'].median())
mode=round(df['price'].mode())

print('\t\t\t\t\t\t Mean: ',mean,'  Median: ',median,'  Mode:',mode[0])
# Out:
# 						 Mean:  314115   Median:  275000   Mode: 249000

# %% [markdown]
# Observation:
#
#
# *   In the above histogram we can see that the third bin with the price between 200,000 to 300,000 has the most numbers of observation.
# *   Majority  of the observations lie within the second to fourth bin.
# *   Mean is 314,115, Median is 275,000 & mode is 249,000 euro.

# %%
# create separate dataframe for house & apartment 


df_house = df[df['type_of_property'] == 0]

df_apartment = df[df['type_of_property'] == 1]

# %%
# plot histrogram for only houses

plt.figure(figsize=(20,10));  # makes the plot wider
plt.hist(df_house['price'], color='r');  # plots a simple histogram
plt.axvline(df_house['price'].mean(), color='m', linewidth=3,label='Mean')  # draw a line for mean
plt.axvline(df_house['price'].median(), color='b', linestyle='dashed', linewidth=3,label='Medium') # draw a line for median
plt.axvline(df_house['price'].mode()[0], color='g', linestyle='dashed', linewidth=3,label='Mode') # draw a line for mode

plt.title('Price for houses in Belgium')
plt.xlabel('Price')    # label the x-axis
plt.ylabel('Numbers of houses')    # label the y-axis
plt.legend()      # Plot the legend

mean=round(df_house['price'].mean())
median=round(df_house['price'].median())
mode=round(df_house['price'].mode())

print('\t\t\t\t\t\t Mean: ',mean,'  Median: ',median,'  Mode:',mode[0])
# Out:
# 						 Mean:  332896   Median:  295000   Mode: 249000

# %% [markdown]
# Observation:
#
#
# *   In the above histogram we can see that the third bin with the price between 200,000 to 300,000 has the most numbers of observation.
# *   Majority  of the observations lie within the second to fifth bin.
# *   Mean is 332,896, Median is 295,000 & mode is 249,000 euro.

# %%
# plot histrogram for only apartment

plt.figure(figsize=(20,10));  # makes the plot wider
plt.hist(df_apartment['price'], color='r');  # plots a simple histogram
plt.axvline(df_apartment['price'].mean(), color='m', linewidth=3,label='Mean')  # draw a line for mean
plt.axvline(df_apartment['price'].median(), color='b', linestyle='dashed', linewidth=3,label='Medium') # draw a line for median
plt.axvline(df_apartment['price'].mode()[0], color='g', linestyle='dashed', linewidth=3,label='Mode') # draw a line for mode

plt.title('Price for apartment in Belgium')
plt.xlabel('Price')    # label the x-axis
plt.ylabel('Numbers of apartment')    # label the y-axis
plt.legend()      # Plot the legend

mean=round(df_apartment['price'].mean())
median=round(df_apartment['price'].median())
mode=round(df_apartment['price'].mode())

print('\t\t\t\t\t\t Mean: ',mean,'  Median: ',median,'  Mode:',mode[0])
# Out:
# 						 Mean:  292871   Median:  250000   Mode: 199000

# %%
# the different of mean,median & mode between house and aparment

print(round(df_house['price'].mean() - df_apartment['price'].mean()))
print(round(df_house['price'].median() - df_apartment['price'].mean()))
print(round(df_house['price'].mode()[0] - df_apartment['price'].mode()[0]))
# Out:
# 40025
# 2129
# 50000

# %% [markdown]
# Observation:
#
# *   In the above histogram we can see that the third bin with the price between 200,000 to 300,000 has the most numbers of observation.
# *   Majority  of the observations lie within the second to fourth bin.
# *   Mean is 292,871, Median is 250,000 & mode is 199,000 euro.
# *   Comparing mean for house and apartment:
#     * mean for houses is 40000  higher than apartment.
#
# *   Comparing median for house and apartment:
#     * median for houses is 2129 higher than apartment
#
# *   Comparing mode for house and apartment:
#     * mode for houses is 50000 higher than apartment

# %%
# Create boxplot for price

plt.figure(figsize=(20,10))
sns.boxplot(x=df["price"]);

# %% [markdown]
# Observation:
#
# *   there are a lot of number of houses or aparments over 650,000 shows as outliers in the box plot.

# %% [markdown]
# ## number_of_rooms

# %%
plt.subplots(figsize=(12, 8))   

sns.countplot(df['number_of_rooms'],hue=df['type_of_property'])

plt.title('Number of rooms with different type of property')

plt.legend(bbox_to_anchor=(1, 1))

# %% [markdown]
# ## house_area

# %%
df['house_area'].describe()
# Out:
# count    40395.000000
# mean       152.466320
# std         95.649206
# min          5.000000
# 25%         92.000000
# 50%        130.000000
# 75%        184.000000
# max       3560.000000
# Name: house_area, dtype: float64

# %%
filt = df['house_area'] > 3000
df[filt]
# Out:
#        postal_code city_name  type_of_property   price  number_of_rooms  \
# 28619         2880    Bornem                 0  750000                3
#
#        house_area  fully_equipped_kitchen  open_fire  terrace  garden  \
# 28619        3560                       1          1        1       1
#
#        surface_of_the_land  number_of_facades  swimming_pool  \
# 28619                 3560                  4              0
#
#       state_of_the_building  longitude  lattitude province   region
# 28619                  good   4.242326  51.092465   Anvers  Flandre

# %%
# plot histrogram for only apartment

plt.figure(figsize=(20,10));   
plt.hist(df['house_area'],bins=20 , color='r');

# %% [markdown]
# ## surface_of_the_land

# %%
# histrogram for surface_of_the_land < 3000
plt.figure(figsize=(20,10));   
plt.hist(df['surface_of_the_land'],bins=20 , color='r');

# %%
df.surface_of_the_land.sort_values()
# Out:
# 20197         0
# 28742         0
# 28747         0
# 28760         0
# 28761         0
#           ...
# 23433    120000
# 36591    120000
# 21114    120300
# 18424    264781
# 27750    400000
# Name: surface_of_the_land, Length: 40395, dtype: int64

# %%
df.surface_of_the_land.describe()
# Out:
# count     40395.000000
# mean        545.840079
# std        3609.242736
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%         416.000000
# max      400000.000000
# Name: surface_of_the_land, dtype: float64

# %% [markdown]
# Commment : surface_of_the_land has highly right skewed distrubution. More than 50% of the observation has 0 surface of land while mean is 545.

# %%
# filter surface_of_the_land > 0 & surface_of_the_land < 3000

filt = (df.surface_of_the_land > 0) & (df.surface_of_the_land < 3000)
temp = df[filt]

# %%
temp.surface_of_the_land.describe()
# Out:
# count    18613.000000
# mean       608.219793
# std        576.941093
# min          1.000000
# 25%        200.000000
# 50%        400.000000
# 75%        822.000000
# max       2996.000000
# Name: surface_of_the_land, dtype: float64

# %%
# histrogram for surface_of_the_land < 3000
plt.figure(figsize=(20,10));   
plt.hist(temp['surface_of_the_land'],bins=20 , color='r');   

plt.title('Surface of Land with less than 3000 sqm')
plt.xlabel('Surface of Land')    # label the x-axis
plt.ylabel('Count')    # label the y-axis
# Out:
# Text(0, 0.5, 'Count')

# %%
# Create boxplot for surface_of_the_land without filter

plt.figure(figsize=(20,10))
sns.boxplot(x=df["surface_of_the_land"]);

# %%
# Create boxplot for surface_of_the_land < 3000

plt.figure(figsize=(20,10))
sns.boxplot(x=temp["surface_of_the_land"]);

# %% [markdown]
# ## state_of_the_building

# %%
plt.subplots(figsize=(12, 8))   

sns.countplot(df['state_of_the_building'],hue=df['type_of_property'])

plt.title('State of the building with different type of property')

plt.legend(bbox_to_anchor=(1, 1))

# %% [markdown]
# # Bivariate Analysis

# %%
# plot pair plot

sns.pairplot(df) # plots scatter plots for every pair of attributes and histograms along the diagonal

# %% [markdown]
# In the above plot scatter diagrams are plotted for all the numerical columns in the dataset. A scatter plot is a visual representation of the degree of correlation between any two columns.

# %%
df.corr() # prints the correlation coefficient between every pair of attributes
# Out:
#                         postal_code  type_of_property     price  \
# postal_code                1.000000         -0.056602 -0.131703
# type_of_property          -0.056602          1.000000 -0.118791
# price                     -0.131703         -0.118791  1.000000
# number_of_rooms           -0.017940         -0.543052  0.418513
# house_area                -0.014097         -0.497931  0.529055
# fully_equipped_kitchen    -0.102069         -0.012888  0.026582
# open_fire                 -0.037909         -0.157901  0.178116
# terrace                   -0.096574          0.135788  0.126296
# garden                     0.027099         -0.352253  0.113077
# surface_of_the_land       -0.004921         -0.142202  0.148578
# number_of_facades         -0.102367         -0.392999  0.133420
# swimming_pool             -0.015533         -0.058169  0.170617
# longitude                 -0.570451         -0.157330 -0.078736
# lattitude                  0.038052          0.248653  0.208369
#
#                         number_of_rooms  house_area  fully_equipped_kitchen  \
# postal_code                   -0.017940   -0.014097               -0.102069
# type_of_property              -0.543052   -0.497931               -0.012888
# price                          0.418513    0.529055                0.026582
# number_of_rooms                1.000000    0.681586                0.022366
# house_area                     0.681586    1.000000               -0.000115
# fully_equipped_kitchen         0.022366   -0.000115                1.000000
# open_fire                      0.161792    0.188162                0.080377
# terrace                       -0.005068   -0.009661                0.095490
# garden                         0.218488    0.189655                0.079302
# surface_of_the_land            0.139943    0.171753               -0.001342
# number_of_facades              0.277610    0.274940                0.119645
# swimming_pool                  0.089100    0.147919                0.029212
# longitude                      0.128281    0.101554                0.060548
# lattitude                     -0.164816   -0.108256               -0.085515
#
#                         open_fire   terrace    garden  surface_of_the_land  \
# postal_code             -0.037909 -0.096574  0.027099            -0.004921
# type_of_property        -0.157901  0.135788 -0.352253            -0.142202
# price                    0.178116  0.126296  0.113077             0.148578
# number_of_rooms          0.161792 -0.005068  0.218488             0.139943
# house_area               0.188162 -0.009661  0.189655             0.171753
# fully_equipped_kitchen   0.080377  0.095490  0.079302            -0.001342
# open_fire                1.000000  0.035855  0.167730             0.059217
# terrace                  0.035855  1.000000  0.057741            -0.003367
# garden                   0.167730  0.057741  1.000000             0.058076
# surface_of_the_land      0.059217 -0.003367  0.058076             1.000000
# number_of_facades        0.164682  0.001834  0.137370             0.105247
# swimming_pool            0.090127  0.048745  0.052322             0.055874
# longitude                0.043475  0.045062  0.037440             0.053901
# lattitude               -0.066810 -0.009285 -0.067247            -0.060302
#
#                         number_of_facades  swimming_pool  longitude  lattitude
# postal_code                     -0.102367      -0.015533  -0.570451   0.038052
# type_of_property                -0.392999      -0.058169  -0.157330   0.248653
# price                            0.133420       0.170617  -0.078736   0.208369
# number_of_rooms                  0.277610       0.089100   0.128281  -0.164816
# house_area                       0.274940       0.147919   0.101554  -0.108256
# fully_equipped_kitchen           0.119645       0.029212   0.060548  -0.085515
# open_fire                        0.164682       0.090127   0.043475  -0.066810
# terrace                          0.001834       0.048745   0.045062  -0.009285
# garden                           0.137370       0.052322   0.037440  -0.067247
# surface_of_the_land              0.105247       0.055874   0.053901  -0.060302
# number_of_facades                1.000000       0.086391   0.223357  -0.202303
# swimming_pool                    0.086391       1.000000   0.019141  -0.020968
# longitude                        0.223357       0.019141   1.000000  -0.429051
# lattitude                       -0.202303      -0.020968  -0.429051   1.000000

# %%
# plot heatmap checking for correlation

fig,ax = plt.subplots(figsize=(12, 12))   
headmap_plot = sns.heatmap(df.corr(), ax=ax, annot=True, linewidths=0.05, fmt= '.2f',cmap="magma")  
plt.show()

figure = headmap_plot.get_figure()    
figure.savefig('Heatmap.png', dpi=100)

# %%
# check the relationship between number of rooms compare with the price
# type_of_property 0 : house , 1 : apartment
plt.subplots(figsize=(12, 12)) 
sns.scatterplot(df['price'], df['number_of_rooms'], hue=df['type_of_property'])

# %%
# check the relationship between house area compare with the price
# type_of_property 0 : house , 1 : apartment
plt.subplots(figsize=(12, 12)) 
sns.scatterplot(df['price'], df['house_area'], hue=df['type_of_property'])

# %%
# check the relationship between house area compare with the price
# type_of_property 0 : house , 1 : apartment
plt.subplots(figsize=(12, 12)) 
sns.scatterplot(df['number_of_rooms'], df['house_area'], hue=df['type_of_property'])

# %% [markdown]
# # For both house & apartment

# %% [markdown]
# ### What are the most & less expensive municipalities in Belgium? (Average price, median price, price per square meter)

# %%
# create new column for price per square meter

df['price_sqm'] = df['price'] / df['house_area']

# %%
df.head()
# Out:
#    postal_code city_name  type_of_property   price  number_of_rooms  \
# 0         1050   Ixelles                 0  340000                6
# 1         1050   Ixelles                 0  520000                4
# 2         1050   Ixelles                 0  599000                4
# 3         1050   Ixelles                 0  599000                3
# 4         1050   Ixelles                 0  575000                3
#
#    house_area  fully_equipped_kitchen  open_fire  terrace  garden  \
# 0         203                       1          0        1       0
# 1         200                       0          0        0       0
# 2         160                       1          0        1       1
# 3         160                       1          0        1       1
# 4         171                       0          0        0       0
#
#    surface_of_the_land  number_of_facades  swimming_pool  \
# 0                   95                  2              0
# 1                   69                  2              0
# 2                  100                  2              0
# 3                  130                  2              0
# 4                   46                  2              0
#
#   state_of_the_building  longitude  lattitude            province     region  \
# 0         to be done up   4.381571  50.822285  Bruxelles-Capitale  Bruxelles
# 1           to renovate   4.381571  50.822285  Bruxelles-Capitale  Bruxelles
# 2         to be done up   4.381571  50.822285  Bruxelles-Capitale  Bruxelles
# 3                  good   4.381571  50.822285  Bruxelles-Capitale  Bruxelles
# 4        just renovated   4.381571  50.822285  Bruxelles-Capitale  Bruxelles
#
#      price_sqm
# 0  1674.876847
# 1  2600.000000
# 2  3743.750000
# 3  3743.750000
# 4  3362.573099

# %%
# most & less expensive municipalities in Belgium by average price/square meter

df.groupby('city_name')['price_sqm'].agg('mean').sort_values()
# Out:
# city_name
# Beauwelz         350.000000
# Focant           390.243902
# Nollevaux        421.212121
# Attre            560.424679
# Roucourt         657.142857
#                    ...
# Heverlee        4148.311309
# Leuven          4600.957816
# Ramskapelle     4697.122149
# Knokke          5924.335983
# Westouter      19671.523810
# Name: price_sqm, Length: 1046, dtype: float64

# %%
filt = df['city_name'] == 'Westouter'

df[filt]
# Out:
#        postal_code  city_name  type_of_property   price  number_of_rooms  \
# 37284         8954  Westouter                 1  207010                2
# 37285         8954  Westouter                 0  207010                2
# 37286         8954  Westouter                 0  265500                3
#
#        house_area  fully_equipped_kitchen  open_fire  terrace  garden  \
# 37284          70                       0          0        0       0
# 37285          70                       0          0        0       0
# 37286           5                       1          0        0       0
#
#        surface_of_the_land  number_of_facades  swimming_pool  \
# 37284                    0                  0              0
# 37285                    0                  0              0
# 37286                  373                  0              0
#
#       state_of_the_building  longitude  lattitude             province  \
# 37284                  good   2.740961  50.800337  Flandre-Occidentale
# 37285                  good   2.740961  50.800337  Flandre-Occidentale
# 37286                as new   2.740961  50.800337  Flandre-Occidentale
#
#         region     price_sqm
# 37284  Flandre   2957.285714
# 37285  Flandre   2957.285714
# 37286  Flandre  53100.000000

# %% [markdown]
# Comment:
#
# house area for index 37286 in Westouter is only 5 square meter and hence the price per sq meter is 53100 which affect the average price per sq meter. drop this row (index 37286) in Westouter for more accurate average price per sq meter in Westouter.

# %%
# drop row 37286 as per comment above

df = df.drop(37286)

# %%
# most expensive city in Belgium

most_expensive = df.groupby('city_name')['price_sqm'].agg('mean').sort_values().idxmax()
most_expensive
# Out:
# 'Knokke'

# %%
filt = df['city_name'] == most_expensive 

average = df[filt]['price'].mean()
median = df[filt]['price'].median()
price_sqm = df[filt]['price_sqm'].mean()

print(f'The most expensive municipalities in Belgium is {most_expensive}.')
print(f'Average price : {average} , median :{median}   price per square meter : {price_sqm}')
# Out:
# The most expensive municipalities in Belgium is Knokke.
# Average price : 568728.0866666667 , median :545000.0   price per square meter : 5924.335983074829

# %%
# less expensive city in Belgium

less_expensive = df.groupby('city_name')['price_sqm'].agg('mean').sort_values().idxmin() 
less_expensive
# Out:
# 'Beauwelz'

# %%
filt = df['city_name'] == less_expensive 

average = df[filt]['price'].mean()
median = df[filt]['price'].median()
price_sqm = df[filt]['price_sqm'].mean()

print(f'The less expensive municipalities in Belgium is {less_expensive}.')
print(f'Average price : {average} , median :{median}   price per square meter : {price_sqm}')
# Out:
# The less expensive municipalities in Belgium is Beauwelz.
# Average price : 70000.0 , median :70000.0   price per square meter : 350.0

# %% [markdown]
# ## What are the most & less expensive municipalities in Wallonia? (Average price, median price, price per square meter)

# %%
# most expensive city in Wallonie

filt1 = df['region'] == 'Wallonie'

df_wallonie = df[filt1]

most_expensive = df_wallonie.groupby('city_name')['price_sqm'].agg('mean').sort_values().idxmax()

filt2 = df_wallonie['city_name'] == most_expensive 

average = df_wallonie[filt2]['price'].mean()
median = df_wallonie[filt2]['price'].median()
price_sqm = df_wallonie[filt2]['price_sqm'].mean()

print(f'The most expensive municipalities in Wallonie is {most_expensive}.')
print(f'Average price : {average} , median :{median}   price per square meter : {price_sqm}')
# Out:
# The most expensive municipalities in Wallonie is Louvain-La-Neuve.
# Average price : 475838.71428571426 , median :490000.0   price per square meter : 3709.738165339578

# %%
# less expensive city in Wallonie

less_expensive = df_wallonie .groupby('city_name')['price_sqm'].agg('mean').sort_values().idxmin() 
less_expensive 

filt3 = df_wallonie['city_name'] == less_expensive 

average = df_wallonie[filt3]['price'].mean()
median = df_wallonie[filt3]['price'].median()
price_sqm = df_wallonie[filt3]['price_sqm'].mean()

print(f'The less expensive municipalities in Wallonie is {less_expensive}.')
print(f'Average price : {average} , median :{median}   price per square meter : {price_sqm}')
# Out:
# The less expensive municipalities in Wallonie is Beauwelz.
# Average price : 70000.0 , median :70000.0   price per square meter : 350.0

# %% [markdown]
# ## What are the most & less expensive municipalities in Flanders? (Average price, median price, price per square meter)

# %%
# most expensive city in Flanders

filt1 = df['region'] == 'Flandre'

df_flanders = df[filt1]

most_expensive = df_flanders.groupby('city_name')['price_sqm'].agg('mean').sort_values().idxmax()

filt2 = df_flanders['city_name'] == most_expensive 

average = df_flanders[filt2]['price'].mean()
median = df_flanders[filt2]['price'].median()
price_sqm = df_flanders[filt2]['price_sqm'].mean()

print(f'The most expensive municipalities in Flanders is {most_expensive}.')
print(f'Average price : {average} , median :{median}   price per square meter : {price_sqm}')
# Out:
# The most expensive municipalities in Flanders is Knokke.
# Average price : 568728.0866666667 , median :545000.0   price per square meter : 5924.335983074829

# %%
# less expensive city in Flanders

less_expensive = df_flanders.groupby('city_name')['price_sqm'].agg('mean').sort_values().idxmin() 
less_expensive 

filt3 = df_flanders['city_name'] == less_expensive 

average = df_flanders[filt3]['price'].mean()
median = df_flanders[filt3]['price'].median()
price_sqm = df_flanders[filt3]['price_sqm'].mean()

print(f'The less expensive municipalities in Flanders is {less_expensive}.')
print(f'Average price : {average} , median :{median}   price per square meter : {price_sqm}')
# Out:
# The less expensive municipalities in Flanders is Bossuit.
# Average price : 220000.0 , median :220000.0   price per square meter : 698.4126984126984

# %% [markdown]
# ## What are the most & less expensive municipalities in Brussels? (Average price, median price, price per square meter)

# %%
# most expensive municipalities in Brussels

filt1 = df['region'] == 'Bruxelles'

df_bruxelles = df[filt1]

most_expensive = df_bruxelles.groupby('city_name')['price_sqm'].agg('mean').sort_values().idxmax()

filt2 = df_bruxelles['city_name'] == most_expensive 

average = df_bruxelles[filt2]['price'].mean()
median = df_bruxelles[filt2]['price'].median()
price_sqm = df_bruxelles[filt2]['price_sqm'].mean()

print(f'The most expensive municipalities in Brussels is {most_expensive}.')
print(f'Average price : {average} , median :{median}   price per square meter : {price_sqm}')
# Out:
# The most expensive municipalities in Brussels is Ixelles.
# Average price : 529083.4489164087 , median :500000.0   price per square meter : 3956.268385456423

# %%
 # less expensive city municipalities in Brussels

less_expensive = df_bruxelles.groupby('city_name')['price_sqm'].agg('mean').sort_values().idxmin() 
less_expensive 

filt3 = df_bruxelles['city_name'] == less_expensive 

average = df_bruxelles[filt3]['price'].mean()
median = df_bruxelles[filt3]['price'].median()
price_sqm = df_bruxelles[filt3]['price_sqm'].mean()

print(f'The less expensive municipalities in Brussels is {less_expensive}.')
print(f'Average price : {average} , median :{median}   price per square meter : {price_sqm}')
# Out:
# The less expensive municipalities in Brussels is Molenbeek-Saint-Jean.
# Average price : 261347.57992565056 , median :235000.0   price per square meter : 2227.022723707461

# %% [markdown]
# # For apartment only

# %% [markdown]
# ## What are the most & less expensive municipalities in Belgium? (Average price, median price, price per square meter)

# %%
df_apartment = df[df['type_of_property'] == 1]
df_apartment.head()
# Out:
#     postal_code city_name  type_of_property   price  number_of_rooms  \
# 33         1050   Ixelles                 1  150000                1
# 34         1050   Ixelles                 1  195000                1
# 35         1050   Ixelles                 1  165000                1
# 36         1050   Ixelles                 1  200000                1
# 37         1050   Ixelles                 1  159000                1
#
#     house_area  fully_equipped_kitchen  open_fire  terrace  garden  \
# 33          36                       1          0        0       0
# 34          37                       1          0        1       0
# 35          34                       1          0        0       0
# 36          75                       1          0        0       0
# 37          34                       1          0        1       1
#
#     surface_of_the_land  number_of_facades  swimming_pool  \
# 33                    0                  4              0
# 34                    0                  2              0
# 35                    0                  2              0
# 36                    0                  2              0
# 37                    0                  2              0
#
#    state_of_the_building  longitude  lattitude            province     region  \
# 33           to renovate   4.381571  50.822285  Bruxelles-Capitale  Bruxelles
# 34                as new   4.381571  50.822285  Bruxelles-Capitale  Bruxelles
# 35         to be done up   4.381571  50.822285  Bruxelles-Capitale  Bruxelles
# 36                as new   4.381571  50.822285  Bruxelles-Capitale  Bruxelles
# 37                  good   4.381571  50.822285  Bruxelles-Capitale  Bruxelles
#
#       price_sqm
# 33  4166.666667
# 34  5270.270270
# 35  4852.941176
# 36  2666.666667
# 37  4676.470588

# %%
# most expensive city in Belgium for apartment

most_expensive = df_apartment.groupby('city_name')['price_sqm'].agg('mean').sort_values().idxmax()

filt1 = df_apartment['city_name'] == most_expensive 

average = df_apartment[filt1]['price'].mean()
median = df_apartment[filt1]['price'].median()
price_sqm = df_apartment[filt1]['price_sqm'].mean()

print(f'The most expensive apartment municipalities in Belgium is {most_expensive}.')
print(f'Average price : {average} , median :{median}   price per square meter : {price_sqm}')
# Out:
# The most expensive apartment municipalities in Belgium is Knokke.
# Average price : 550494.3406593406 , median :515000.0   price per square meter : 6363.917694600006

# %%
# less expensive city in Belgium for apartment

less_expensive = df_apartment.groupby('city_name')['price_sqm'].agg('mean').sort_values().idxmin() 

filt2 = df_apartment['city_name'] == less_expensive 

average = df_apartment[filt2]['price'].mean()
median = df_apartment[filt2]['price'].median()
price_sqm = df_apartment[filt2]['price_sqm'].mean()

print(f'The less expensive apartment municipalities in Belgium is {less_expensive}.')
print(f'Average price : {average} , median :{median}   price per square meter : {price_sqm}')
# Out:
# The less expensive apartment municipalities in Belgium is Villers-Sur-Semois.
# Average price : 14500.0 , median :14500.0   price per square meter : 517.8571428571429

# %% [markdown]
# ## What are the most & less expensive municipalities in Wallonia? (Average price, median price, price per square meter)

# %%
# most expensive city in Wallonie for apartment

filt1 = df_apartment['region'] == 'Wallonie'

df_wallonie = df_apartment[filt1]

most_expensive = df_wallonie.groupby('city_name')['price_sqm'].agg('mean').sort_values().idxmax()

filt2 = df_wallonie['city_name'] == most_expensive 

average = df_wallonie[filt2]['price'].mean()
median = df_wallonie[filt2]['price'].median()
price_sqm = df_wallonie[filt2]['price_sqm'].mean()

print(f'The most expensive municipalities in Wallonie for apartment is {most_expensive}.')
print(f'Average price : {average} , median :{median}   price per square meter : {price_sqm}')
# Out:
# The most expensive municipalities in Wallonie for apartment is La Hulpe.
# Average price : 346000.0 , median :332500.0   price per square meter : 3898.2758363985013

# %% [markdown]
# investigate La Hulpe to find out if it is the most expensive city for apartment

# %%
df_wallonie.groupby('city_name')['price_sqm'].agg('mean').sort_values()
# Out:
# city_name
# Villers-Sur-Semois        517.857143
# Rosée                     646.551724
# Jemappes                  706.521739
# Chastrès                  733.644860
# Torgny                    825.396825
#                             ...
# Genval                   3589.651177
# Couture-Saint-Germain    3608.499246
# Ottignies                3633.228932
# Louvain-La-Neuve         3881.633071
# La Hulpe                 3898.275836
# Name: price_sqm, Length: 303, dtype: float64

# %%
filt = df_wallonie['city_name'] == 'La Hulpe'

print(df_wallonie[filt]['price_sqm'].describe())

df_wallonie[filt]
# Out:
# count      12.000000
# mean     3898.275836
# std       759.457758
# min      2692.307692
# 25%      3384.946950
# 50%      3799.019608
# 75%      4600.082713
# max      4983.333333
# Name: price_sqm, dtype: float64
#        postal_code city_name  type_of_property   price  number_of_rooms  \
# 29663         1310  La Hulpe                 1  225000                2
# 29664         1310  La Hulpe                 1  299000                1
# 29665         1310  La Hulpe                 1  295000                1
# 29666         1310  La Hulpe                 1  295000                1
# 29667         1310  La Hulpe                 1  265000                2
# 29668         1310  La Hulpe                 1  349000                2
# 29669         1310  La Hulpe                 1  320000                2
# 29670         1310  La Hulpe                 1  350000                1
# 29671         1310  La Hulpe                 1  345000                2
# 29672         1310  La Hulpe                 1  415000                3
# 29673         1310  La Hulpe                 1  445000                2
# 29674         1310  La Hulpe                 1  549000                3
#
#        house_area  fully_equipped_kitchen  open_fire  terrace  garden  \
# 29663          65                       0          0        0       0
# 29664          60                       0          0        1       0
# 29665          61                       1          0        1       0
# 29666          65                       1          0        1       0
# 29667          87                       1          0        1       0
# 29668          85                       0          0        1       0
# 29669          85                       1          0        1       0
# 29670         130                       1          0        1       0
# 29671          90                       1          0        1       0
# 29672         116                       1          0        1       0
# 29673          93                       0          0        1       1
# 29674         174                       0          0        1       0
#
#        surface_of_the_land  number_of_facades  swimming_pool  \
# 29663                    0                  2              0
# 29664                    0                  0              0
# 29665                    0                  2              0
# 29666                    0                  4              0
# 29667                    0                  3              0
# 29668                    0                  0              0
# 29669                    0                  0              0
# 29670                    0                  0              0
# 29671                    0                  3              0
# 29672                    0                  0              0
# 29673                    0                  0              0
# 29674                    0                  0              0
#
#       state_of_the_building  longitude  lattitude        province    region  \
# 29663                  good   4.479654  50.731505  Brabant wallon  Wallonie
# 29664                as new   4.479654  50.731505  Brabant wallon  Wallonie
# 29665                as new   4.479654  50.731505  Brabant wallon  Wallonie
# 29666               unknown   4.479654  50.731505  Brabant wallon  Wallonie
# 29667         to be done up   4.479654  50.731505  Brabant wallon  Wallonie
# 29668                as new   4.479654  50.731505  Brabant wallon  Wallonie
# 29669               unknown   4.479654  50.731505  Brabant wallon  Wallonie
# 29670                as new   4.479654  50.731505  Brabant wallon  Wallonie
# 29671               unknown   4.479654  50.731505  Brabant wallon  Wallonie
# 29672                as new   4.479654  50.731505  Brabant wallon  Wallonie
# 29673                as new   4.479654  50.731505  Brabant wallon  Wallonie
# 29674                as new   4.479654  50.731505  Brabant wallon  Wallonie
#
#          price_sqm
# 29663  3461.538462
# 29664  4983.333333
# 29665  4836.065574
# 29666  4538.461538
# 29667  3045.977011
# 29668  4105.882353
# 29669  3764.705882
# 29670  2692.307692
# 29671  3833.333333
# 29672  3577.586207
# 29673  4784.946237
# 29674  3155.172414

# %% [markdown]
# comment : based on the 12 rows of data for La Hulpe for apartment , the average of 3898 /sqm seems correct. The apartement area range from 60-174 sqm which is normal.

# %%
filt = df_wallonie['city_name'] == 'Louvain-La-Neuve'

print(df_wallonie[filt]['price_sqm'].describe())

df_wallonie[filt]
# Out:
# count      32.000000
# mean     3881.633071
# std       437.123528
# min      2931.034483
# 25%      3706.144722
# 50%      3874.269006
# 75%      4089.192810
# max      5416.666667
# Name: price_sqm, dtype: float64
#        postal_code         city_name  type_of_property   price  \
# 31881         1348  Louvain-La-Neuve                 1  149000
# 31882         1348  Louvain-La-Neuve                 1  190000
# 31883         1348  Louvain-La-Neuve                 1  245000
# 31884         1348  Louvain-La-Neuve                 1  269000
# 31885         1348  Louvain-La-Neuve                 1  275000
# 31886         1348  Louvain-La-Neuve                 1  285000
# 31887         1348  Louvain-La-Neuve                 1  295000
# 31888         1348  Louvain-La-Neuve                 1  280000
# 31889         1348  Louvain-La-Neuve                 1  315000
# 31890         1348  Louvain-La-Neuve                 1  399000
# 31891         1348  Louvain-La-Neuve                 1  364000
# 31892         1348  Louvain-La-Neuve                 1  375000
# 31893         1348  Louvain-La-Neuve                 1  415000
# 31894         1348  Louvain-La-Neuve                 1  425000
# 31895         1348  Louvain-La-Neuve                 1  450000
# 31896         1348  Louvain-La-Neuve                 1  415000
# 31897         1348  Louvain-La-Neuve                 1  440000
# 31898         1348  Louvain-La-Neuve                 1  490000
# 31899         1348  Louvain-La-Neuve                 1  490031
# 31900         1348  Louvain-La-Neuve                 1  460000
# 31901         1348  Louvain-La-Neuve                 1  495000
# 31902         1348  Louvain-La-Neuve                 1  490000
# 31903         1348  Louvain-La-Neuve                 1  546861
# 31904         1348  Louvain-La-Neuve                 1  525190
# 31905         1348  Louvain-La-Neuve                 1  551190
# 31906         1348  Louvain-La-Neuve                 1  595000
# 31907         1348  Louvain-La-Neuve                 1  642309
# 31908         1348  Louvain-La-Neuve                 1  628336
# 31909         1348  Louvain-La-Neuve                 1  650000
# 31910         1348  Louvain-La-Neuve                 1  621000
# 31911         1348  Louvain-La-Neuve                 1  602309
# 31912         1348  Louvain-La-Neuve                 1  660000
#
#        number_of_rooms  house_area  fully_equipped_kitchen  open_fire  \
# 31881                1          35                       1          0
# 31882                1          45                       1          0
# 31883                1          63                       0          0
# 31884                2          72                       1          0
# 31885                1          68                       1          0
# 31886                2          85                       0          0
# 31887                1          79                       1          0
# 31888                1          85                       0          0
# 31889                2          96                       1          0
# 31890                2         120                       1          0
# 31891                2          83                       1          0
# 31892                3         100                       1          0
# 31893                3         110                       1          0
# 31894                3         103                       1          0
# 31895                3         114                       1          0
# 31896                3         109                       0          0
# 31897                3         114                       1          0
# 31898                1         120                       1          0
# 31899                2         138                       1          0
# 31900                3         127                       1          0
# 31901                3         127                       0          0
# 31902                1         120                       0          1
# 31903                2         127                       1          0
# 31904                2         137                       0          0
# 31905                2         137                       1          0
# 31906                3         203                       0          0
# 31907                3         153                       1          0
# 31908                3         153                       1          0
# 31909                3         120                       1          0
# 31910                3         161                       1          0
# 31911                3         154                       0          0
# 31912                3         183                       0          0
#
#        terrace  garden  surface_of_the_land  number_of_facades  swimming_pool  \
# 31881        0       0                    0                  2              0
# 31882        0       0                    0                  2              0
# 31883        0       0                    0                  0              0
# 31884        0       0                    0                  2              0
# 31885        1       1                    0                  0              0
# 31886        1       0                    0                  0              0
# 31887        1       1                    0                  2              0
# 31888        0       0                    0                  0              0
# 31889        1       1                    0                  4              0
# 31890        1       0                    0                  2              0
# 31891        1       1                    0                  4              0
# 31892        1       0                    0                  0              0
# 31893        1       1                    0                  2              0
# 31894        1       1                    0                  3              0
# 31895        1       1                    0                  3              0
# 31896        1       0                    0                  0              0
# 31897        1       1                    0                  3              0
# 31898        1       0                    0                  2              0
# 31899        1       0                    0                  0              0
# 31900        1       1                    0                  3              0
# 31901        1       0                    0                  0              0
# 31902        1       0                    0                  2              0
# 31903        1       0                    0                  0              0
# 31904        1       0                    0                  2              0
# 31905        1       0                    0                  0              0
# 31906        1       1                    0                  4              0
# 31907        1       0                    0                  0              0
# 31908        1       0                    0                  0              0
# 31909        1       1                    0                  3              0
# 31910        1       0                    0                  0              0
# 31911        1       0                    0                  3              0
# 31912        1       0                    0                  4              0
#
#       state_of_the_building  longitude  lattitude        province    region  \
# 31881                  good   4.614157  50.674169  Brabant wallon  Wallonie
# 31882                  good   4.614157  50.674169  Brabant wallon  Wallonie
# 31883                as new   4.614157  50.674169  Brabant wallon  Wallonie
# 31884                  good   4.614157  50.674169  Brabant wallon  Wallonie
# 31885                as new   4.614157  50.674169  Brabant wallon  Wallonie
# 31886                as new   4.614157  50.674169  Brabant wallon  Wallonie
# 31887                as new   4.614157  50.674169  Brabant wallon  Wallonie
# 31888               unknown   4.614157  50.674169  Brabant wallon  Wallonie
# 31889                as new   4.614157  50.674169  Brabant wallon  Wallonie
# 31890                as new   4.614157  50.674169  Brabant wallon  Wallonie
# 31891                as new   4.614157  50.674169  Brabant wallon  Wallonie
# 31892                as new   4.614157  50.674169  Brabant wallon  Wallonie
# 31893                as new   4.614157  50.674169  Brabant wallon  Wallonie
# 31894                as new   4.614157  50.674169  Brabant wallon  Wallonie
# 31895                as new   4.614157  50.674169  Brabant wallon  Wallonie
# 31896                as new   4.614157  50.674169  Brabant wallon  Wallonie
# 31897                as new   4.614157  50.674169  Brabant wallon  Wallonie
# 31898                as new   4.614157  50.674169  Brabant wallon  Wallonie
# 31899                as new   4.614157  50.674169  Brabant wallon  Wallonie
# 31900                as new   4.614157  50.674169  Brabant wallon  Wallonie
# 31901               unknown   4.614157  50.674169  Brabant wallon  Wallonie
# 31902                as new   4.614157  50.674169  Brabant wallon  Wallonie
# 31903                as new   4.614157  50.674169  Brabant wallon  Wallonie
# 31904                as new   4.614157  50.674169  Brabant wallon  Wallonie
# 31905                as new   4.614157  50.674169  Brabant wallon  Wallonie
# 31906                as new   4.614157  50.674169  Brabant wallon  Wallonie
# 31907                as new   4.614157  50.674169  Brabant wallon  Wallonie
# 31908                as new   4.614157  50.674169  Brabant wallon  Wallonie
# 31909                as new   4.614157  50.674169  Brabant wallon  Wallonie
# 31910                as new   4.614157  50.674169  Brabant wallon  Wallonie
# 31911                as new   4.614157  50.674169  Brabant wallon  Wallonie
# 31912                as new   4.614157  50.674169  Brabant wallon  Wallonie
#
#          price_sqm
# 31881  4257.142857
# 31882  4222.222222
# 31883  3888.888889
# 31884  3736.111111
# 31885  4044.117647
# 31886  3352.941176
# 31887  3734.177215
# 31888  3294.117647
# 31889  3281.250000
# 31890  3325.000000
# 31891  4385.542169
# 31892  3750.000000
# 31893  3772.727273
# 31894  4126.213592
# 31895  3947.368421
# 31896  3807.339450
# 31897  3859.649123
# 31898  4083.333333
# 31899  3550.949275
# 31900  3622.047244
# 31901  3897.637795
# 31902  4083.333333
# 31903  4305.992126
# 31904  3833.503650
# 31905  4023.284672
# 31906  2931.034483
# 31907  4198.098039
# 31908  4106.771242
# 31909  5416.666667
# 31910  3857.142857
# 31911  3911.097403
# 31912  3606.557377

# %% [markdown]
# comment: the second most expenseive city for apartment in Wallonia is Louvain-La-Neuve where it has more apartment on sale ( 32 ) and the mean price per square meter is 3881 slightly lower than La Hulpe (3898).

# %%
# less expensive city in Wallonie for apartment

less_expensive = df_wallonie.groupby('city_name')['price_sqm'].agg('mean').sort_values().idxmin() 
less_expensive 

filt3 = df_wallonie['city_name'] == less_expensive 

average = df_wallonie[filt3]['price'].mean()
median = df_wallonie[filt3]['price'].median()
price_sqm = df_wallonie[filt3]['price_sqm'].mean()

print(f'The less expensive municipalities in Wallonie for apartment is {less_expensive}.')
print(f'Average price : {average} , median :{median}   price per square meter : {price_sqm}')
# Out:
# The less expensive municipalities in Wallonie for apartment is Villers-Sur-Semois.
# Average price : 14500.0 , median :14500.0   price per square meter : 517.8571428571429

# %% [markdown]
# ## What are the most & less expensive municipalities in Flanders? (Average price, median price, price per square meter)

# %%
# most expensive city in Flanders for apartment

filt1 = df_apartment['region'] == 'Flandre'

df_flanders = df_apartment[filt1]

most_expensive = df_flanders.groupby('city_name')['price_sqm'].agg('mean').sort_values().idxmax()

filt2 = df_flanders['city_name'] == most_expensive 

average = df_flanders[filt2]['price'].mean()
median = df_flanders[filt2]['price'].median()
price_sqm = df_flanders[filt2]['price_sqm'].mean()

print(f'The most expensive municipalities in Flanders is {most_expensive}.')
print(f'Average price : {average} , median :{median}   price per square meter : {price_sqm}')
# Out:
# The most expensive municipalities in Flanders is Knokke.
# Average price : 550494.3406593406 , median :515000.0   price per square meter : 6363.917694600006

# %%
# less expensive city in Flanders for apartment

less_expensive = df_flanders.groupby('city_name')['price_sqm'].agg('mean').sort_values().idxmin() 
less_expensive 

filt3 = df_flanders['city_name'] == less_expensive 

average = df_flanders[filt3]['price'].mean()
median = df_flanders[filt3]['price'].median()
price_sqm = df_flanders[filt3]['price_sqm'].mean()

print(f'The less expensive municipalities in Flanders is {less_expensive}.')
print(f'Average price : {average} , median :{median}   price per square meter : {price_sqm}')
# Out:
# The less expensive municipalities in Flanders is Kermt.
# Average price : 229500.0 , median :229500.0   price per square meter : 1213.869463869464

# %% [markdown]
# ## What are the most & less expensive municipalities in Brussels? (Average price, median price, price per square meter)

# %%
# most expensive municipalities in Brussels for apartment

filt1 = df_apartment['region'] == 'Bruxelles'

df_bruxelles = df_apartment[filt1]

most_expensive = df_bruxelles.groupby('city_name')['price_sqm'].agg('mean').sort_values().idxmax()

filt2 = df_bruxelles['city_name'] == most_expensive 

average = df_bruxelles[filt2]['price'].mean()
median = df_bruxelles[filt2]['price'].median()
price_sqm = df_bruxelles[filt2]['price_sqm'].mean()

print(f'The most expensive municipalities in Brussels is {most_expensive}.')
print(f'Average price : {average} , median :{median}   price per square meter : {price_sqm}')
# Out:
# The most expensive municipalities in Brussels is Auderghem.
# Average price : 429326.92307692306 , median :392500.0   price per square meter : 4191.968437745178

# %%
# less expensive city municipalities in Brussels for apartment

less_expensive = df_bruxelles.groupby('city_name')['price_sqm'].agg('mean').sort_values().idxmin() 

filt3 = df_bruxelles['city_name'] == less_expensive 

average = df_bruxelles[filt3]['price'].mean()
median = df_bruxelles[filt3]['price'].median()
price_sqm = df_bruxelles[filt3]['price_sqm'].mean()

print(f'The less expensive municipalities in Brussels is {less_expensive}.')
print(f'Average price : {average} , median :{median}   price per square meter : {price_sqm}')
# Out:
# The less expensive municipalities in Brussels is Molenbeek-Saint-Jean.
# Average price : 234724.44 , median :219000.0   price per square meter : 2288.214348586766

# %% [markdown]
# # For house only

# %%
df_house = df[df['type_of_property'] == 0]
df_house.head()
# Out:
#    postal_code city_name  type_of_property   price  number_of_rooms  \
# 0         1050   Ixelles                 0  340000                6
# 1         1050   Ixelles                 0  520000                4
# 2         1050   Ixelles                 0  599000                4
# 3         1050   Ixelles                 0  599000                3
# 4         1050   Ixelles                 0  575000                3
#
#    house_area  fully_equipped_kitchen  open_fire  terrace  garden  \
# 0         203                       1          0        1       0
# 1         200                       0          0        0       0
# 2         160                       1          0        1       1
# 3         160                       1          0        1       1
# 4         171                       0          0        0       0
#
#    surface_of_the_land  number_of_facades  swimming_pool  \
# 0                   95                  2              0
# 1                   69                  2              0
# 2                  100                  2              0
# 3                  130                  2              0
# 4                   46                  2              0
#
#   state_of_the_building  longitude  lattitude            province     region  \
# 0         to be done up   4.381571  50.822285  Bruxelles-Capitale  Bruxelles
# 1           to renovate   4.381571  50.822285  Bruxelles-Capitale  Bruxelles
# 2         to be done up   4.381571  50.822285  Bruxelles-Capitale  Bruxelles
# 3                  good   4.381571  50.822285  Bruxelles-Capitale  Bruxelles
# 4        just renovated   4.381571  50.822285  Bruxelles-Capitale  Bruxelles
#
#      price_sqm
# 0  1674.876847
# 1  2600.000000
# 2  3743.750000
# 3  3743.750000
# 4  3362.573099

# %%
df_house['surface_of_the_land'].describe()
# Out:
# count     21439.000000
# mean       1028.445217
# std        4903.952004
# min           0.000000
# 25%         163.000000
# 50%         380.000000
# 75%         870.000000
# max      400000.000000
# Name: surface_of_the_land, dtype: float64

# %%
df_house['surface_of_the_land'].value_counts().sort_values()
# Out:
# 1959       1
# 3885       1
# 1836       1
# 3869       1
# 1804       1
#         ...
# 300      144
# 1000     145
# 200      160
# 150      169
# 0       1796
# Name: surface_of_the_land, Length: 2952, dtype: int64

# %%
filt = df_house['surface_of_the_land'] > 300000
df_house[filt]
# Out:
#        postal_code       city_name  type_of_property   price  number_of_rooms  \
# 27750         1910  Nederokkerzeel                 0  945000                4
#
#        house_area  fully_equipped_kitchen  open_fire  terrace  garden  \
# 27750         350                       1          0        1       1
#
#        surface_of_the_land  number_of_facades  swimming_pool  \
# 27750               400000                  0              0
#
#       state_of_the_building  longitude  lattitude         province   region  \
# 27750                as new    4.56451  50.919013  Brabant flamand  Flandre
#
#        price_sqm
# 27750     2700.0

# %% [markdown]
# comment : due to the surface of land has enormous number i.e 400,000.
# See link: https://www.immoweb.be/en/classified/villa/for-sale/kampenhout/1910/8805057
#
# To calculate house price per sq meter, we will use the house area to calculate instead of surface of the land.

# %% [markdown]
# ## What are the most & less expensive municipalities in Belgium? (Average price, median price, price per square meter)

# %%
# most expensive city in Belgium for house

most_expensive = df_house.groupby('city_name')['price_sqm'].agg('mean').sort_values().idxmax()

filt1 = df_house['city_name'] == most_expensive 

average = df_house[filt1]['price'].mean()
median = df_house[filt1]['price'].median()
price_sqm = df_house[filt1]['price_sqm'].mean()

print(f'The most expensive municipalities in Belgium for house is {most_expensive}.')
print(f'Average price : {average} , median :{median}   price per square meter : {price_sqm}')
# Out:
# The most expensive municipalities in Belgium for house is Boutersem.
# Average price : 443245.8333333333 , median :360000.0   price per square meter : 3750.529467335884

# %% [markdown]
# ## What are the most & less expensive municipalities in Wallonia? (Average price, median price, price per square meter)

# %%
# most expensive city in Wallonie for house

filt1 = df_house['region'] == 'Wallonie'

df_wallonie = df_house[filt1]

most_expensive = df_wallonie.groupby('city_name')['price_sqm'].agg('mean').sort_values().idxmax()

filt2 = df_wallonie['city_name'] == most_expensive 

average = df_wallonie[filt2]['price'].mean()
median = df_wallonie[filt2]['price'].median()
price_sqm = df_wallonie[filt2]['price_sqm'].mean()

print(f'The most expensive municipalities in Wallonie for house is {most_expensive}.')
print(f'Average price : {average} , median :{median}   price per square meter : {price_sqm}')
# Out:
# The most expensive municipalities in Wallonie for house is Thines.
# Average price : 550000.0 , median :550000.0   price per square meter : 3437.5

# %%
filt = df_house['city_name'] == 'Thines'
df_house[filt]
# Out:
#        postal_code city_name  type_of_property   price  number_of_rooms  \
# 32749         1402    Thines                 0  550000                4
#
#        house_area  fully_equipped_kitchen  open_fire  terrace  garden  \
# 32749         160                       1          0        1       1
#
#        surface_of_the_land  number_of_facades  swimming_pool  \
# 32749                 1600                  4              0
#
#       state_of_the_building  longitude  lattitude        province    region  \
# 32749         to be done up   4.382595  50.586787  Brabant wallon  Wallonie
#
#        price_sqm
# 32749     3437.5

# %% [markdown]
# comment : Thines only one house on sale , and the avereage price/sqm is not representative. Consider drop this row (index 32749)

# %%
# drop row 32749 as per comment above

df = df.drop(32749)

# %%
df_house = df[df['type_of_property'] == 0]
df_house.head()
# Out:
#    postal_code city_name  type_of_property   price  number_of_rooms  \
# 0         1050   Ixelles                 0  340000                6
# 1         1050   Ixelles                 0  520000                4
# 2         1050   Ixelles                 0  599000                4
# 3         1050   Ixelles                 0  599000                3
# 4         1050   Ixelles                 0  575000                3
#
#    house_area  fully_equipped_kitchen  open_fire  terrace  garden  \
# 0         203                       1          0        1       0
# 1         200                       0          0        0       0
# 2         160                       1          0        1       1
# 3         160                       1          0        1       1
# 4         171                       0          0        0       0
#
#    surface_of_the_land  number_of_facades  swimming_pool  \
# 0                   95                  2              0
# 1                   69                  2              0
# 2                  100                  2              0
# 3                  130                  2              0
# 4                   46                  2              0
#
#   state_of_the_building  longitude  lattitude            province     region  \
# 0         to be done up   4.381571  50.822285  Bruxelles-Capitale  Bruxelles
# 1           to renovate   4.381571  50.822285  Bruxelles-Capitale  Bruxelles
# 2         to be done up   4.381571  50.822285  Bruxelles-Capitale  Bruxelles
# 3                  good   4.381571  50.822285  Bruxelles-Capitale  Bruxelles
# 4        just renovated   4.381571  50.822285  Bruxelles-Capitale  Bruxelles
#
#      price_sqm
# 0  1674.876847
# 1  2600.000000
# 2  3743.750000
# 3  3743.750000
# 4  3362.573099

# %%
# most expensive city in Wallonie for house

filt1 = df_house['region'] == 'Wallonie'

df_wallonie = df_house[filt1]

most_expensive = df_wallonie.groupby('city_name')['price_sqm'].agg('mean').sort_values().idxmax()

filt2 = df_wallonie['city_name'] == most_expensive 

average = df_wallonie[filt2]['price'].mean()
median = df_wallonie[filt2]['price'].median()
price_sqm = df_wallonie[filt2]['price_sqm'].mean()

print(f'The most expensive municipalities in Wallonie for house is {most_expensive}.')
print(f'Average price : {average} , median :{median}   price per square meter : {price_sqm}')
# Out:
# The most expensive municipalities in Wallonie for house is Louvain-La-Neuve.
# Average price : 595200.0 , median :580000.0   price per square meter : 3159.6744656271494

# %%
# less expensive city in Wallonie for house

less_expensive = df_wallonie.groupby('city_name')['price_sqm'].agg('mean').sort_values().idxmin() 
less_expensive 

filt3 = df_wallonie['city_name'] == less_expensive 

average = df_wallonie[filt3]['price'].mean()
median = df_wallonie[filt3]['price'].median()
price_sqm = df_wallonie[filt3]['price_sqm'].mean()

print(f'The less expensive municipalities in Wallonie for house is {less_expensive}.')
print(f'Average price : {average} , median :{median}   price per square meter : {price_sqm}')
# Out:
# The less expensive municipalities in Wallonie for house is Beauwelz.
# Average price : 70000.0 , median :70000.0   price per square meter : 350.0

# %% [markdown]
# ## What are the most & less expensive municipalities in Flanders? (Average price, median price, price per square meter)

# %%
# most expensive city in Flanders for house

filt1 = df_house['region'] == 'Flandre'

df_flanders = df_house[filt1]

most_expensive = df_flanders.groupby('city_name')['price_sqm'].agg('mean').sort_values().idxmax()

filt2 = df_flanders['city_name'] == most_expensive 

average = df_flanders[filt2]['price'].mean()
median = df_flanders[filt2]['price'].median()
price_sqm = df_flanders[filt2]['price_sqm'].mean()

print(f'The most expensive municipalities in Flanders for house is {most_expensive}.')
print(f'Average price : {average} , median :{median}   price per square meter : {price_sqm}')
# Out:
# The most expensive municipalities in Flanders for house is Boutersem.
# Average price : 443245.8333333333 , median :360000.0   price per square meter : 3750.529467335884

# %%
# less expensive city in Flanders for house

less_expensive = df_flanders.groupby('city_name')['price_sqm'].agg('mean').sort_values().idxmin() 
less_expensive 

filt3 = df_flanders['city_name'] == less_expensive 

average = df_flanders[filt3]['price'].mean()
median = df_flanders[filt3]['price'].median()
price_sqm = df_flanders[filt3]['price_sqm'].mean()

print(f'The less expensive municipalities in Flanders for house is {less_expensive}.')
print(f'Average price : {average} , median :{median}   price per square meter : {price_sqm}')
# Out:
# The less expensive municipalities in Flanders for house is Bossuit.
# Average price : 220000.0 , median :220000.0   price per square meter : 698.4126984126984

# %% [markdown]
# ## What are the most & less expensive municipalities in Brussels? (Average price, median price, price per square meter)

# %%
# most expensive municipalities in Brussels for house
filt1 = df_house['region'] == 'Bruxelles'

df_bruxelles = df_house[filt1]

most_expensive = df_bruxelles.groupby('city_name')['price_sqm'].agg('mean').sort_values().idxmax()

filt2 = df_bruxelles['city_name'] == most_expensive 

average = df_bruxelles[filt2]['price'].mean()
median = df_bruxelles[filt2]['price'].median()
price_sqm = df_bruxelles[filt2]['price_sqm'].mean()

print(f'The most expensive municipalities in Brussels for house is {most_expensive}.')
print(f'Average price : {average} , median :{median}   price per square meter : {price_sqm}')
# Out:
# The most expensive municipalities in Brussels for house is Watermael-Boitsfort.
# Average price : 637965.5172413794 , median :595000.0   price per square meter : 3426.3137471603595

# %%
# less expensive city municipalities in Brussels for house

less_expensive = df_bruxelles.groupby('city_name')['price_sqm'].agg('mean').sort_values().idxmin() 

filt3 = df_bruxelles['city_name'] == less_expensive 

average = df_bruxelles[filt3]['price'].mean()
median = df_bruxelles[filt3]['price'].median()
price_sqm = df_bruxelles[filt3]['price_sqm'].mean()

print(f'The less expensive municipalities in Brussels for house is {less_expensive}.')
print(f'Average price : {average} , median :{median}   price per square meter : {price_sqm}')
# Out:
# The less expensive municipalities in Brussels for house is Koekelberg.
# Average price : 377500.0 , median :330000.0   price per square meter : 1725.2076967719045

# %% [markdown]
# ## For Apartment

# %%
df_map_apartment = df_apartment[['postal_code','city_name','price_sqm']]

# %%
# get average price/sqm for each city

cols = [ val for val in df_map_apartment.columns]
temp = pd.concat([df_map_apartment.groupby(['city_name'])[cols].mean()],axis=1).reset_index()
temp
# Out:
#           city_name  postal_code    price_sqm
# 0    's Gravenwezel       2970.0  3291.178998
# 1             Aalst       9300.0  2507.656390
# 2            Aalter       9880.0  2611.213039
# 3         Aartrijke       8211.0  2552.596857
# 4        Aartselaar       2630.0  2847.632058
# ..              ...          ...          ...
# 707        Zonhoven       3520.0  2186.545043
# 708           Zulte       9870.0  2307.215402
# 709       Zutendaal       3690.0  2694.452144
# 710        Zwevegem       8550.0  2674.249421
# 711      Zwijnaarde       9052.0  3080.652587
#
# [712 rows x 3 columns]

# %%
# merging city other information

df_map1 = df_apartment[['region','province','city_name','longitude','lattitude']]
 
df_map2 = pd.merge(temp,df_map1,on='city_name',how='inner')

# drop duplicates results
df_map2.drop_duplicates(inplace=True)
df_map2
# Out:
#             city_name  postal_code    price_sqm   region             province  \
# 0      's Gravenwezel       2970.0  3291.178998  Flandre               Anvers
# 11              Aalst       9300.0  2507.656390  Flandre    Flandre-Orientale
# 159            Aalter       9880.0  2611.213039  Flandre    Flandre-Orientale
# 229         Aartrijke       8211.0  2552.596857  Flandre  Flandre-Occidentale
# 237        Aartselaar       2630.0  2847.632058  Flandre               Anvers
# ...               ...          ...          ...      ...                  ...
# 18870        Zonhoven       3520.0  2186.545043  Flandre             Limbourg
# 18894           Zulte       9870.0  2307.215402  Flandre    Flandre-Orientale
# 18905       Zutendaal       3690.0  2694.452144  Flandre             Limbourg
# 18933        Zwevegem       8550.0  2674.249421  Flandre  Flandre-Occidentale
# 18947      Zwijnaarde       9052.0  3080.652587  Flandre    Flandre-Orientale
#
#        longitude  lattitude
# 0       4.555604  51.262486
# 11      4.039642  50.942976
# 159     3.417680  51.088195
# 229     3.091327  51.118000
# 237     4.387024  51.133297
# ...          ...        ...
# 18870   5.367768  50.990983
# 18894   3.448563  50.920664
# 18905   5.572555  50.931899
# 18933   3.341907  50.804070
# 18947   3.702179  51.000922
#
# [716 rows x 7 columns]

# %%
# checking duplicated city_name

df_map2[df_map2.duplicated(['city_name'], keep=False)]
# Out:
#      city_name  postal_code    price_sqm   region             province  \
# 1947   Berchem  2865.046729  2706.659842  Flandre               Anvers
# 2050   Berchem  2865.046729  2706.659842  Flandre    Flandre-Orientale
# 2165   Beveren  8799.362832  2237.340491  Flandre  Flandre-Occidentale
# 2270   Beveren  8799.362832  2237.340491  Flandre  Flandre-Occidentale
# 4522    Deurne  2214.191919  2323.500018  Flandre      Brabant flamand
# 4541    Deurne  2214.191919  2323.500018  Flandre               Anvers
# 7364     Halle  1587.058824  2867.616691  Flandre               Anvers
# 7369     Halle  1587.058824  2867.616691  Flandre      Brabant flamand
#
#       longitude  lattitude
# 1947   4.431703  51.191849
# 2050   3.508267  50.790392
# 2165   3.144160  50.968731
# 2270   3.342747  50.871701
# 4522   5.096457  51.039238
# 4541   4.469525  51.211528
# 7364   4.645557  51.242845
# 7369   4.237435  50.736052

# %%
# drop duplicated city name with different province name
df_map2 = df_map2.drop([2050,2270,4541,7369])

# %%
df_map2.price_sqm.sort_values(ascending=True)
# Out:
# 17331     517.857143
# 14846     646.551724
# 8777      706.521739
# 4143      733.644860
# 16135     825.396825
#             ...
# 10502    5035.075630
# 8091     5108.401332
# 15913    5173.076923
# 10598    5298.080939
# 9204     6363.917695
# Name: price_sqm, Length: 712, dtype: float64

# %%
df_map2.to_csv('apartment_price_sqm.csv',index=False)

# %% [markdown]
# ## For House

# %%
df_map_house = df_house[['postal_code','city_name','price_sqm']]

# %%
# get average price/sqm for each city

cols = [ val for val in df_map_house.columns]
temp = pd.concat([df_map_house.groupby(['city_name'])[cols].mean()],axis=1).reset_index()
temp
# Out:
#            city_name  postal_code    price_sqm
# 0     's Gravenwezel       2970.0  2219.785091
# 1            Aalbeke       8511.0  1193.970020
# 2              Aalst       9300.0  1620.400809
# 3             Aalter       9880.0  2479.997504
# 4          Aartrijke       8211.0  1856.934688
# ...              ...          ...          ...
# 1036        Zonhoven       3520.0  1700.126441
# 1037           Zulte       9870.0  1862.715382
# 1038       Zutendaal       3690.0  2458.215506
# 1039        Zwevegem       8550.0  1543.887224
# 1040      Zwijnaarde       9052.0  2203.514056
#
# [1041 rows x 3 columns]

# %%
# merging city other information

df_map1 = df_house[['region','province','city_name','longitude','lattitude']]
 
df_map2 = pd.merge(temp,df_map1,on='city_name',how='inner')

# drop duplicates results
df_map2.drop_duplicates(inplace=True)
df_map2
# Out:
#             city_name  postal_code    price_sqm   region             province  \
# 0      's Gravenwezel       2970.0  2219.785091  Flandre               Anvers
# 25            Aalbeke       8511.0  1193.970020  Flandre  Flandre-Occidentale
# 33              Aalst       9300.0  1620.400809  Flandre    Flandre-Orientale
# 174            Aalter       9880.0  2479.997504  Flandre    Flandre-Orientale
# 191         Aartrijke       8211.0  1856.934688  Flandre  Flandre-Occidentale
# ...               ...          ...          ...      ...                  ...
# 21332        Zonhoven       3520.0  1700.126441  Flandre             Limbourg
# 21377           Zulte       9870.0  1862.715382  Flandre    Flandre-Orientale
# 21401       Zutendaal       3690.0  2458.215506  Flandre             Limbourg
# 21405        Zwevegem       8550.0  1543.887224  Flandre  Flandre-Occidentale
# 21432      Zwijnaarde       9052.0  2203.514056  Flandre    Flandre-Orientale
#
#        longitude  lattitude
# 0       4.555604  51.262486
# 25      3.218605  50.777455
# 33      4.039642  50.942976
# 174     3.417680  51.088195
# 191     3.091327  51.118000
# ...          ...        ...
# 21332   5.367768  50.990983
# 21377   3.448563  50.920664
# 21401   5.572555  50.931899
# 21405   3.341907  50.804070
# 21432   3.702179  51.000922
#
# [1046 rows x 7 columns]

# %%
# checking duplicated city_name

df_map2[df_map2.duplicated(['city_name'], keep=False)]
# Out:
#       city_name  postal_code    price_sqm   region             province  \
# 2008    Berchem  5296.197183  2049.337512  Flandre               Anvers
# 2052    Berchem  5296.197183  2049.337512  Flandre    Flandre-Orientale
# 2292    Beveren  8799.068966  2199.039267  Flandre  Flandre-Occidentale
# 2422    Beveren  8799.068966  2199.039267  Flandre  Flandre-Occidentale
# 5519     Deurne  2443.063063  1886.288609  Flandre      Brabant flamand
# 5551     Deurne  2443.063063  1886.288609  Flandre               Anvers
# 9063      Halle  2003.829787  2024.195163  Flandre               Anvers
# 9095      Halle  2003.829787  2024.195163  Flandre      Brabant flamand
# 11286  Kapellen  2962.676471  1992.561367  Flandre               Anvers
# 11319  Kapellen  2962.676471  1992.561367  Flandre      Brabant flamand
#
#        longitude  lattitude
# 2008    4.431703  51.191849
# 2052    3.508267  50.790392
# 2292    3.144160  50.968731
# 2422    3.342747  50.871701
# 5519    5.096457  51.039238
# 5551    4.469525  51.211528
# 9063    4.645557  51.242845
# 9095    4.237435  50.736052
# 11286   4.431232  51.332759
# 11319   4.960878  50.887345

# %%
# drop duplicated city name with different province name
df_map2 = df_map2.drop([2052,2422,5551,9095,11319	])

# %%
df_map2.price_sqm.sort_values(ascending=True)
# Out:
# 1762      350.000000
# 7016      390.243902
# 15726     421.212121
# 8486      482.758621
# 1254      560.424679
#             ...
# 15763    3333.069628
# 20878    3419.049762
# 20303    3426.313747
# 11538    3446.339963
# 3769     3750.529467
# Name: price_sqm, Length: 1041, dtype: float64

# %%
df_map2.to_csv('house_price_sqm.csv',index=False)
